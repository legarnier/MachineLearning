# %% [markdown]
# ## Import data

# %%
# !unzip drive/MyDrive/INF8770_TP3_A2023.zip
# Out:
# Archive:  drive/MyDrive/INF8770_TP3_A2023.zip
#    creating: src/
#   inflating: src/evaluate.py
#    creating: data/
#    creating: data/challenge/
#    creating: data/challenge/jpeg/
#   inflating: data/challenge/jpeg/i001.jpeg
#   inflating: data/challenge/jpeg/i002.jpeg
#   inflating: data/challenge/jpeg/i003.jpeg
#   inflating: data/challenge/jpeg/i004.jpeg
#   inflating: data/challenge/jpeg/i005.jpeg
#   inflating: data/challenge/jpeg/i006.jpeg
#   inflating: data/challenge/jpeg/i007.jpeg
#   inflating: data/challenge/jpeg/i008.jpeg
#   inflating: data/challenge/jpeg/i009.jpeg
#   inflating: data/challenge/jpeg/i010.jpeg
#   inflating: data/challenge/jpeg/i011.jpeg
#   inflating: data/challenge/jpeg/i012.jpeg
#   inflating: data/challenge/jpeg/i013.jpeg
#   inflating: data/challenge/jpeg/i014.jpeg
#   inflating: data/challenge/jpeg/i015.jpeg
#   inflating: data/challenge/jpeg/i016.jpeg
#   inflating: data/challenge/jpeg/i017.jpeg
#   inflating: data/challenge/jpeg/i018.jpeg
#   inflating: data/challenge/jpeg/i019.jpeg
#   inflating: data/challenge/jpeg/i020.jpeg
#   inflating: data/challenge/jpeg/i021.jpeg
#   inflating: data/challenge/jpeg/i022.jpeg
#   inflating: data/challenge/jpeg/i023.jpeg
#   inflating: data/challenge/jpeg/i024.jpeg
#   inflating: data/challenge/jpeg/i025.jpeg
#   inflating: data/challenge/jpeg/i026.jpeg
#   inflating: data/challenge/jpeg/i027.jpeg
#   inflating: data/challenge/jpeg/i028.jpeg
#   inflating: data/challenge/jpeg/i029.jpeg
#   inflating: data/challenge/jpeg/i030.jpeg
#   inflating: data/challenge/jpeg/i031.jpeg
#   inflating: data/challenge/jpeg/i032.jpeg
#   inflating: data/challenge/jpeg/i033.jpeg
#   inflating: data/challenge/jpeg/i034.jpeg
#   inflating: data/challenge/jpeg/i035.jpeg
#   inflating: data/challenge/jpeg/i036.jpeg
#   inflating: data/challenge/jpeg/i037.jpeg
#   inflating: data/challenge/jpeg/i038.jpeg
#   inflating: data/challenge/jpeg/i039.jpeg
#   inflating: data/challenge/jpeg/i040.jpeg
#   inflating: data/challenge/jpeg/i041.jpeg
#   inflating: data/challenge/jpeg/i042.jpeg
#   inflating: data/challenge/jpeg/i043.jpeg
#   inflating: data/challenge/jpeg/i044.jpeg
#   inflating: data/challenge/jpeg/i045.jpeg
#   inflating: data/challenge/jpeg/i046.jpeg
#   inflating: data/challenge/jpeg/i047.jpeg
#   inflating: data/challenge/jpeg/i048.jpeg
#   inflating: data/challenge/jpeg/i049.jpeg
#   inflating: data/challenge/jpeg/i050.jpeg
#   inflating: data/challenge/jpeg/i051.jpeg
#   inflating: data/challenge/jpeg/i052.jpeg
#   inflating: data/challenge/jpeg/i053.jpeg
#   inflating: data/challenge/jpeg/i054.jpeg
#   inflating: data/challenge/jpeg/i055.jpeg
#   inflating: data/challenge/jpeg/i056.jpeg
#   inflating: data/challenge/jpeg/i057.jpeg
#   inflating: data/challenge/jpeg/i058.jpeg
#   inflating: data/challenge/jpeg/i059.jpeg
#   inflating: data/challenge/jpeg/i060.jpeg
#   inflating: data/challenge/jpeg/i061.jpeg
#   inflating: data/challenge/jpeg/i062.jpeg
#   inflating: data/challenge/jpeg/i063.jpeg
#   inflating: data/challenge/jpeg/i064.jpeg
#   inflating: data/challenge/jpeg/i065.jpeg
#   inflating: data/challenge/jpeg/i066.jpeg
#   inflating: data/challenge/jpeg/i067.jpeg
#   inflating: data/challenge/jpeg/i068.jpeg
#   inflating: data/challenge/jpeg/i069.jpeg
#   inflating: data/challenge/jpeg/i070.jpeg
#   inflating: data/challenge/jpeg/i071.jpeg
#   inflating: data/challenge/jpeg/i072.jpeg
#   inflating: data/challenge/jpeg/i073.jpeg
#   inflating: data/challenge/jpeg/i074.jpeg
#   inflating: data/challenge/jpeg/i075.jpeg
#   inflating: data/challenge/jpeg/i076.jpeg
#   inflating: data/challenge/jpeg/i077.jpeg
#   inflating: data/challenge/jpeg/i078.jpeg
#   inflating: data/challenge/jpeg/i079.jpeg
#   inflating: data/challenge/jpeg/i080.jpeg
#   inflating: data/challenge/jpeg/i081.jpeg
#   inflating: data/challenge/jpeg/i082.jpeg
#   inflating: data/challenge/jpeg/i083.jpeg
#   inflating: data/challenge/jpeg/i084.jpeg
#   inflating: data/challenge/jpeg/i085.jpeg
#   inflating: data/challenge/jpeg/i086.jpeg
#   inflating: data/challenge/jpeg/i087.jpeg
#   inflating: data/challenge/jpeg/i088.jpeg
#   inflating: data/challenge/jpeg/i089.jpeg
#   inflating: data/challenge/jpeg/i090.jpeg
#   inflating: data/challenge/jpeg/i091.jpeg
#   inflating: data/challenge/jpeg/i092.jpeg
#   inflating: data/challenge/jpeg/i093.jpeg
#   inflating: data/challenge/jpeg/i094.jpeg
#   inflating: data/challenge/jpeg/i095.jpeg
#   inflating: data/challenge/jpeg/i096.jpeg
#   inflating: data/challenge/jpeg/i097.jpeg
#   inflating: data/challenge/jpeg/i098.jpeg
#   inflating: data/challenge/jpeg/i099.jpeg
#   inflating: data/challenge/jpeg/i100.jpeg
#   inflating: data/challenge/jpeg/i101.jpeg
#   inflating: data/challenge/jpeg/i102.jpeg
#   inflating: data/challenge/jpeg/i103.jpeg
#   inflating: data/challenge/jpeg/i104.jpeg
#   inflating: data/challenge/jpeg/i105.jpeg
#   inflating: data/challenge/jpeg/i106.jpeg
#   inflating: data/challenge/jpeg/i107.jpeg
#   inflating: data/challenge/jpeg/i108.jpeg
#   inflating: data/challenge/jpeg/i109.jpeg
#   inflating: data/challenge/jpeg/i110.jpeg
#   inflating: data/challenge/jpeg/i111.jpeg
#   inflating: data/challenge/jpeg/i112.jpeg
#   inflating: data/challenge/jpeg/i113.jpeg
#   inflating: data/challenge/jpeg/i114.jpeg
#   inflating: data/challenge/jpeg/i115.jpeg
#   inflating: data/challenge/jpeg/i116.jpeg
#   inflating: data/challenge/jpeg/i117.jpeg
#   inflating: data/challenge/jpeg/i118.jpeg
#   inflating: data/challenge/jpeg/i119.jpeg
#   inflating: data/challenge/jpeg/i120.jpeg
#   inflating: data/challenge/jpeg/i121.jpeg
#   inflating: data/challenge/jpeg/i122.jpeg
#   inflating: data/challenge/jpeg/i123.jpeg
#   inflating: data/challenge/jpeg/i124.jpeg
#   inflating: data/challenge/jpeg/i125.jpeg
#   inflating: data/challenge/jpeg/i126.jpeg
#   inflating: data/challenge/jpeg/i127.jpeg
#   inflating: data/challenge/jpeg/i128.jpeg
#   inflating: data/challenge/jpeg/i129.jpeg
#   inflating: data/challenge/jpeg/i130.jpeg
#   inflating: data/challenge/jpeg/i131.jpeg
#   inflating: data/challenge/jpeg/i132.jpeg
#   inflating: data/challenge/jpeg/i133.jpeg
#   inflating: data/challenge/jpeg/i134.jpeg
#   inflating: data/challenge/jpeg/i135.jpeg
#   inflating: data/challenge/jpeg/i136.jpeg
#   inflating: data/challenge/jpeg/i137.jpeg
#   inflating: data/challenge/jpeg/i138.jpeg
#   inflating: data/challenge/jpeg/i139.jpeg
#   inflating: data/challenge/jpeg/i140.jpeg
#   inflating: data/challenge/jpeg/i141.jpeg
#   inflating: data/challenge/jpeg/i142.jpeg
#   inflating: data/challenge/jpeg/i143.jpeg
#   inflating: data/challenge/jpeg/i144.jpeg
#   inflating: data/challenge/jpeg/i145.jpeg
#   inflating: data/challenge/jpeg/i146.jpeg
#   inflating: data/challenge/jpeg/i147.jpeg
#   inflating: data/challenge/jpeg/i148.jpeg
#   inflating: data/challenge/jpeg/i149.jpeg
#   inflating: data/challenge/jpeg/i150.jpeg
#   inflating: data/challenge/jpeg/i151.jpeg
#   inflating: data/challenge/jpeg/i152.jpeg
#   inflating: data/challenge/jpeg/i153.jpeg
#   inflating: data/challenge/jpeg/i154.jpeg
#   inflating: data/challenge/jpeg/i155.jpeg
#   inflating: data/challenge/jpeg/i156.jpeg
#   inflating: data/challenge/jpeg/i157.jpeg
#   inflating: data/challenge/jpeg/i158.jpeg
#   inflating: data/challenge/jpeg/i159.jpeg
#   inflating: data/challenge/jpeg/i160.jpeg
#   inflating: data/challenge/jpeg/i161.jpeg
#   inflating: data/challenge/jpeg/i162.jpeg
#   inflating: data/challenge/jpeg/i163.jpeg
#   inflating: data/challenge/jpeg/i164.jpeg
#   inflating: data/challenge/jpeg/i165.jpeg
#   inflating: data/challenge/jpeg/i166.jpeg
#   inflating: data/challenge/jpeg/i167.jpeg
#   inflating: data/challenge/jpeg/i168.jpeg
#   inflating: data/challenge/jpeg/i169.jpeg
#   inflating: data/challenge/jpeg/i170.jpeg
#   inflating: data/challenge/jpeg/i171.jpeg
#   inflating: data/challenge/jpeg/i172.jpeg
#   inflating: data/challenge/jpeg/i173.jpeg
#   inflating: data/challenge/jpeg/i174.jpeg
#   inflating: data/challenge/jpeg/i175.jpeg
#   inflating: data/challenge/jpeg/i176.jpeg
#   inflating: data/challenge/jpeg/i177.jpeg
#   inflating: data/challenge/jpeg/i178.jpeg
#   inflating: data/challenge/jpeg/i179.jpeg
#   inflating: data/challenge/jpeg/i180.jpeg
#   inflating: data/challenge/jpeg/i181.jpeg
#   inflating: data/challenge/jpeg/i182.jpeg
#   inflating: data/challenge/jpeg/i183.jpeg
#   inflating: data/challenge/jpeg/i184.jpeg
#   inflating: data/challenge/jpeg/i185.jpeg
#   inflating: data/challenge/jpeg/i186.jpeg
#   inflating: data/challenge/jpeg/i187.jpeg
#   inflating: data/challenge/jpeg/i188.jpeg
#   inflating: data/challenge/jpeg/i189.jpeg
#   inflating: data/challenge/jpeg/i190.jpeg
#   inflating: data/challenge/jpeg/i191.jpeg
#   inflating: data/challenge/jpeg/i192.jpeg
#   inflating: data/challenge/jpeg/i193.jpeg
#   inflating: data/challenge/jpeg/i194.jpeg
#   inflating: data/challenge/jpeg/i195.jpeg
#   inflating: data/challenge/jpeg/i196.jpeg
#   inflating: data/challenge/jpeg/i197.jpeg
#   inflating: data/challenge/jpeg/i198.jpeg
#   inflating: data/challenge/jpeg/i199.jpeg
#   inflating: data/challenge/jpeg/i200.jpeg
#   inflating: data/challenge/jpeg/i201.jpeg
#   inflating: data/challenge/jpeg/i202.jpeg
#   inflating: data/challenge/jpeg/i203.jpeg
#   inflating: data/challenge/jpeg/i204.jpeg
#   inflating: data/challenge/jpeg/i205.jpeg
#   inflating: data/challenge/jpeg/i206.jpeg
#   inflating: data/challenge/jpeg/i207.jpeg
#   inflating: data/challenge/jpeg/i208.jpeg
#   inflating: data/challenge/jpeg/i209.jpeg
#   inflating: data/challenge/jpeg/i210.jpeg
#   inflating: data/challenge/jpeg/i211.jpeg
#   inflating: data/challenge/jpeg/i212.jpeg
#   inflating: data/challenge/jpeg/i213.jpeg
#   inflating: data/challenge/jpeg/i214.jpeg
#   inflating: data/challenge/jpeg/i215.jpeg
#   inflating: data/challenge/jpeg/i216.jpeg
#   inflating: data/challenge/jpeg/i217.jpeg
#   inflating: data/challenge/jpeg/i218.jpeg
#   inflating: data/challenge/jpeg/i219.jpeg
#   inflating: data/challenge/jpeg/i220.jpeg
#   inflating: data/challenge/jpeg/i221.jpeg
#   inflating: data/challenge/jpeg/i222.jpeg
#   inflating: data/challenge/jpeg/i223.jpeg
#   inflating: data/challenge/jpeg/i224.jpeg
#   inflating: data/challenge/jpeg/i225.jpeg
#   inflating: data/challenge/jpeg/i226.jpeg
#   inflating: data/challenge/jpeg/i227.jpeg
#   inflating: data/challenge/jpeg/i228.jpeg
#   inflating: data/challenge/jpeg/i229.jpeg
#   inflating: data/challenge/jpeg/i230.jpeg
#   inflating: data/challenge/jpeg/i231.jpeg
#   inflating: data/challenge/jpeg/i232.jpeg
#   inflating: data/challenge/jpeg/i233.jpeg
#   inflating: data/challenge/jpeg/i234.jpeg
#   inflating: data/challenge/jpeg/i235.jpeg
#   inflating: data/challenge/jpeg/i236.jpeg
#   inflating: data/challenge/jpeg/i237.jpeg
#   inflating: data/challenge/jpeg/i238.jpeg
#   inflating: data/challenge/jpeg/i239.jpeg
#   inflating: data/challenge/jpeg/i240.jpeg
#   inflating: data/challenge/jpeg/i241.jpeg
#   inflating: data/challenge/jpeg/i242.jpeg
#   inflating: data/challenge/jpeg/i243.jpeg
#   inflating: data/challenge/jpeg/i244.jpeg
#   inflating: data/challenge/jpeg/i245.jpeg
#   inflating: data/challenge/jpeg/i246.jpeg
#   inflating: data/challenge/jpeg/i247.jpeg
#   inflating: data/challenge/jpeg/i248.jpeg
#   inflating: data/challenge/jpeg/i249.jpeg
#   inflating: data/challenge/jpeg/i250.jpeg
#   inflating: data/challenge/jpeg/i251.jpeg
#   inflating: data/challenge/jpeg/i252.jpeg
#   inflating: data/challenge/jpeg/i253.jpeg
#   inflating: data/challenge/jpeg/i254.jpeg
#   inflating: data/challenge/jpeg/i255.jpeg
#   inflating: data/challenge/jpeg/i256.jpeg
#   inflating: data/challenge/jpeg/i257.jpeg
#   inflating: data/challenge/jpeg/i258.jpeg
#   inflating: data/challenge/jpeg/i259.jpeg
#   inflating: data/challenge/jpeg/i260.jpeg
#   inflating: data/challenge/jpeg/i261.jpeg
#   inflating: data/challenge/jpeg/i262.jpeg
#   inflating: data/challenge/jpeg/i263.jpeg
#   inflating: data/challenge/jpeg/i264.jpeg
#   inflating: data/challenge/jpeg/i265.jpeg
#   inflating: data/challenge/jpeg/i266.jpeg
#   inflating: data/challenge/jpeg/i267.jpeg
#   inflating: data/challenge/jpeg/i268.jpeg
#   inflating: data/challenge/jpeg/i269.jpeg
#   inflating: data/challenge/jpeg/i270.jpeg
#   inflating: data/challenge/jpeg/i271.jpeg
#   inflating: data/challenge/jpeg/i272.jpeg
#   inflating: data/challenge/jpeg/i273.jpeg
#   inflating: data/challenge/jpeg/i274.jpeg
#   inflating: data/challenge/jpeg/i275.jpeg
#   inflating: data/challenge/jpeg/i276.jpeg
#   inflating: data/challenge/jpeg/i277.jpeg
#   inflating: data/challenge/jpeg/i278.jpeg
#   inflating: data/challenge/jpeg/i279.jpeg
#   inflating: data/challenge/jpeg/i280.jpeg
#   inflating: data/challenge/jpeg/i281.jpeg
#   inflating: data/challenge/jpeg/i282.jpeg
#   inflating: data/challenge/jpeg/i283.jpeg
#   inflating: data/challenge/jpeg/i284.jpeg
#   inflating: data/challenge/jpeg/i285.jpeg
#   inflating: data/challenge/jpeg/i286.jpeg
#   inflating: data/challenge/jpeg/i287.jpeg
#   inflating: data/challenge/jpeg/i288.jpeg
#   inflating: data/challenge/jpeg/i289.jpeg
#   inflating: data/challenge/jpeg/i290.jpeg
#   inflating: data/challenge/jpeg/i291.jpeg
#   inflating: data/challenge/jpeg/i292.jpeg
#   inflating: data/challenge/jpeg/i293.jpeg
#   inflating: data/challenge/jpeg/i294.jpeg
#   inflating: data/challenge/jpeg/i295.jpeg
#   inflating: data/challenge/jpeg/i296.jpeg
#   inflating: data/challenge/jpeg/i297.jpeg
#   inflating: data/challenge/jpeg/i298.jpeg
#   inflating: data/challenge/jpeg/i299.jpeg
#   inflating: data/challenge/jpeg/i300.jpeg
#    creating: data/challenge/png/
#   inflating: data/challenge/png/i001.png
#   inflating: data/challenge/png/i002.png
#   inflating: data/challenge/png/i003.png
#   inflating: data/challenge/png/i004.png
#   inflating: data/challenge/png/i005.png
#   inflating: data/challenge/png/i006.png
#   inflating: data/challenge/png/i007.png
#   inflating: data/challenge/png/i008.png
#   inflating: data/challenge/png/i009.png
#   inflating: data/challenge/png/i010.png
#   inflating: data/challenge/png/i011.png
#   inflating: data/challenge/png/i012.png
#   inflating: data/challenge/png/i013.png
#   inflating: data/challenge/png/i014.png
#   inflating: data/challenge/png/i015.png
#   inflating: data/challenge/png/i016.png
#   inflating: data/challenge/png/i017.png
#   inflating: data/challenge/png/i018.png
#   inflating: data/challenge/png/i019.png
#   inflating: data/challenge/png/i020.png
#   inflating: data/challenge/png/i021.png
#   inflating: data/challenge/png/i022.png
#   inflating: data/challenge/png/i023.png
#   inflating: data/challenge/png/i024.png
#   inflating: data/challenge/png/i025.png
#   inflating: data/challenge/png/i026.png
#   inflating: data/challenge/png/i027.png
#   inflating: data/challenge/png/i028.png
#   inflating: data/challenge/png/i029.png
#   inflating: data/challenge/png/i030.png
#   inflating: data/challenge/png/i031.png
#   inflating: data/challenge/png/i032.png
#   inflating: data/challenge/png/i033.png
#   inflating: data/challenge/png/i034.png
#   inflating: data/challenge/png/i035.png
#   inflating: data/challenge/png/i036.png
#   inflating: data/challenge/png/i037.png
#   inflating: data/challenge/png/i038.png
#   inflating: data/challenge/png/i039.png
#   inflating: data/challenge/png/i040.png
#   inflating: data/challenge/png/i041.png
#   inflating: data/challenge/png/i042.png
#   inflating: data/challenge/png/i043.png
#   inflating: data/challenge/png/i044.png
#   inflating: data/challenge/png/i045.png
#   inflating: data/challenge/png/i046.png
#   inflating: data/challenge/png/i047.png
#   inflating: data/challenge/png/i048.png
#   inflating: data/challenge/png/i049.png
#   inflating: data/challenge/png/i050.png
#   inflating: data/challenge/png/i051.png
#   inflating: data/challenge/png/i052.png
#   inflating: data/challenge/png/i053.png
#   inflating: data/challenge/png/i054.png
#   inflating: data/challenge/png/i055.png
#   inflating: data/challenge/png/i056.png
#   inflating: data/challenge/png/i057.png
#   inflating: data/challenge/png/i058.png
#   inflating: data/challenge/png/i059.png
#   inflating: data/challenge/png/i060.png
#   inflating: data/challenge/png/i061.png
#   inflating: data/challenge/png/i062.png
#   inflating: data/challenge/png/i063.png
#   inflating: data/challenge/png/i064.png
#   inflating: data/challenge/png/i065.png
#   inflating: data/challenge/png/i066.png
#   inflating: data/challenge/png/i067.png
#   inflating: data/challenge/png/i068.png
#   inflating: data/challenge/png/i069.png
#   inflating: data/challenge/png/i070.png
#   inflating: data/challenge/png/i071.png
#   inflating: data/challenge/png/i072.png
#   inflating: data/challenge/png/i073.png
#   inflating: data/challenge/png/i074.png
#   inflating: data/challenge/png/i075.png
#   inflating: data/challenge/png/i076.png
#   inflating: data/challenge/png/i077.png
#   inflating: data/challenge/png/i078.png
#   inflating: data/challenge/png/i079.png
#   inflating: data/challenge/png/i080.png
#   inflating: data/challenge/png/i081.png
#   inflating: data/challenge/png/i082.png
#   inflating: data/challenge/png/i083.png
#   inflating: data/challenge/png/i084.png
#   inflating: data/challenge/png/i085.png
#   inflating: data/challenge/png/i086.png
#   inflating: data/challenge/png/i087.png
#   inflating: data/challenge/png/i088.png
#   inflating: data/challenge/png/i089.png
#   inflating: data/challenge/png/i090.png
#   inflating: data/challenge/png/i091.png
#   inflating: data/challenge/png/i092.png
#   inflating: data/challenge/png/i093.png
#   inflating: data/challenge/png/i094.png
#   inflating: data/challenge/png/i095.png
#   inflating: data/challenge/png/i096.png
#   inflating: data/challenge/png/i097.png
#   inflating: data/challenge/png/i098.png
#   inflating: data/challenge/png/i099.png
#   inflating: data/challenge/png/i100.png
#   inflating: data/challenge/png/i101.png
#   inflating: data/challenge/png/i102.png
#   inflating: data/challenge/png/i103.png
#   inflating: data/challenge/png/i104.png
#   inflating: data/challenge/png/i105.png
#   inflating: data/challenge/png/i106.png
#   inflating: data/challenge/png/i107.png
#   inflating: data/challenge/png/i108.png
#   inflating: data/challenge/png/i109.png
#   inflating: data/challenge/png/i110.png
#   inflating: data/challenge/png/i111.png
#   inflating: data/challenge/png/i112.png
#   inflating: data/challenge/png/i113.png
#   inflating: data/challenge/png/i114.png
#   inflating: data/challenge/png/i115.png
#   inflating: data/challenge/png/i116.png
#   inflating: data/challenge/png/i117.png
#   inflating: data/challenge/png/i118.png
#   inflating: data/challenge/png/i119.png
#   inflating: data/challenge/png/i120.png
#   inflating: data/challenge/png/i121.png
#   inflating: data/challenge/png/i122.png
#   inflating: data/challenge/png/i123.png
#   inflating: data/challenge/png/i124.png
#   inflating: data/challenge/png/i125.png
#   inflating: data/challenge/png/i126.png
#   inflating: data/challenge/png/i127.png
#   inflating: data/challenge/png/i128.png
#   inflating: data/challenge/png/i129.png
#   inflating: data/challenge/png/i130.png
#   inflating: data/challenge/png/i131.png
#   inflating: data/challenge/png/i132.png
#   inflating: data/challenge/png/i133.png
#   inflating: data/challenge/png/i134.png
#   inflating: data/challenge/png/i135.png
#   inflating: data/challenge/png/i136.png
#   inflating: data/challenge/png/i137.png
#   inflating: data/challenge/png/i138.png
#   inflating: data/challenge/png/i139.png
#   inflating: data/challenge/png/i140.png
#   inflating: data/challenge/png/i141.png
#   inflating: data/challenge/png/i142.png
#   inflating: data/challenge/png/i143.png
#   inflating: data/challenge/png/i144.png
#   inflating: data/challenge/png/i145.png
#   inflating: data/challenge/png/i146.png
#   inflating: data/challenge/png/i147.png
#   inflating: data/challenge/png/i148.png
#   inflating: data/challenge/png/i149.png
#   inflating: data/challenge/png/i150.png
#   inflating: data/challenge/png/i151.png
#   inflating: data/challenge/png/i152.png
#   inflating: data/challenge/png/i153.png
#   inflating: data/challenge/png/i154.png
#   inflating: data/challenge/png/i155.png
#   inflating: data/challenge/png/i156.png
#   inflating: data/challenge/png/i157.png
#   inflating: data/challenge/png/i158.png
#   inflating: data/challenge/png/i159.png
#   inflating: data/challenge/png/i160.png
#   inflating: data/challenge/png/i161.png
#   inflating: data/challenge/png/i162.png
#   inflating: data/challenge/png/i163.png
#   inflating: data/challenge/png/i164.png
#   inflating: data/challenge/png/i165.png
#   inflating: data/challenge/png/i166.png
#   inflating: data/challenge/png/i167.png
#   inflating: data/challenge/png/i168.png
#   inflating: data/challenge/png/i169.png
#   inflating: data/challenge/png/i170.png
#   inflating: data/challenge/png/i171.png
#   inflating: data/challenge/png/i172.png
#   inflating: data/challenge/png/i173.png
#   inflating: data/challenge/png/i174.png
#   inflating: data/challenge/png/i175.png
#   inflating: data/challenge/png/i176.png
#   inflating: data/challenge/png/i177.png
#   inflating: data/challenge/png/i178.png
#   inflating: data/challenge/png/i179.png
#   inflating: data/challenge/png/i180.png
#   inflating: data/challenge/png/i181.png
#   inflating: data/challenge/png/i182.png
#   inflating: data/challenge/png/i183.png
#   inflating: data/challenge/png/i184.png
#   inflating: data/challenge/png/i185.png
#   inflating: data/challenge/png/i186.png
#   inflating: data/challenge/png/i187.png
#   inflating: data/challenge/png/i188.png
#   inflating: data/challenge/png/i189.png
#   inflating: data/challenge/png/i190.png
#   inflating: data/challenge/png/i191.png
#   inflating: data/challenge/png/i192.png
#   inflating: data/challenge/png/i193.png
#   inflating: data/challenge/png/i194.png
#   inflating: data/challenge/png/i195.png
#   inflating: data/challenge/png/i196.png
#   inflating: data/challenge/png/i197.png
#   inflating: data/challenge/png/i198.png
#   inflating: data/challenge/png/i199.png
#   inflating: data/challenge/png/i200.png
#   inflating: data/challenge/png/i201.png
#   inflating: data/challenge/png/i202.png
#   inflating: data/challenge/png/i203.png
#   inflating: data/challenge/png/i204.png
#   inflating: data/challenge/png/i205.png
#   inflating: data/challenge/png/i206.png
#   inflating: data/challenge/png/i207.png
#   inflating: data/challenge/png/i208.png
#   inflating: data/challenge/png/i209.png
#   inflating: data/challenge/png/i210.png
#   inflating: data/challenge/png/i211.png
#   inflating: data/challenge/png/i212.png
#   inflating: data/challenge/png/i213.png
#   inflating: data/challenge/png/i214.png
#   inflating: data/challenge/png/i215.png
#   inflating: data/challenge/png/i216.png
#   inflating: data/challenge/png/i217.png
#   inflating: data/challenge/png/i218.png
#   inflating: data/challenge/png/i219.png
#   inflating: data/challenge/png/i220.png
#   inflating: data/challenge/png/i221.png
#   inflating: data/challenge/png/i222.png
#   inflating: data/challenge/png/i223.png
#   inflating: data/challenge/png/i224.png
#   inflating: data/challenge/png/i225.png
#   inflating: data/challenge/png/i226.png
#   inflating: data/challenge/png/i227.png
#   inflating: data/challenge/png/i228.png
#   inflating: data/challenge/png/i229.png
#   inflating: data/challenge/png/i230.png
#   inflating: data/challenge/png/i231.png
#   inflating: data/challenge/png/i232.png
#   inflating: data/challenge/png/i233.png
#   inflating: data/challenge/png/i234.png
#   inflating: data/challenge/png/i235.png
#   inflating: data/challenge/png/i236.png
#   inflating: data/challenge/png/i237.png
#   inflating: data/challenge/png/i238.png
#   inflating: data/challenge/png/i239.png
#   inflating: data/challenge/png/i240.png
#   inflating: data/challenge/png/i241.png
#   inflating: data/challenge/png/i242.png
#   inflating: data/challenge/png/i243.png
#   inflating: data/challenge/png/i244.png
#   inflating: data/challenge/png/i245.png
#   inflating: data/challenge/png/i246.png
#   inflating: data/challenge/png/i247.png
#   inflating: data/challenge/png/i248.png
#   inflating: data/challenge/png/i249.png
#   inflating: data/challenge/png/i250.png
#   inflating: data/challenge/png/i251.png
#   inflating: data/challenge/png/i252.png
#   inflating: data/challenge/png/i253.png
#   inflating: data/challenge/png/i254.png
#   inflating: data/challenge/png/i255.png
#   inflating: data/challenge/png/i256.png
#   inflating: data/challenge/png/i257.png
#   inflating: data/challenge/png/i258.png
#   inflating: data/challenge/png/i259.png
#   inflating: data/challenge/png/i260.png
#   inflating: data/challenge/png/i261.png
#   inflating: data/challenge/png/i262.png
#   inflating: data/challenge/png/i263.png
#   inflating: data/challenge/png/i264.png
#   inflating: data/challenge/png/i265.png
#   inflating: data/challenge/png/i266.png
#   inflating: data/challenge/png/i267.png
#   inflating: data/challenge/png/i268.png
#   inflating: data/challenge/png/i269.png
#   inflating: data/challenge/png/i270.png
#   inflating: data/challenge/png/i271.png
#   inflating: data/challenge/png/i272.png
#   inflating: data/challenge/png/i273.png
#   inflating: data/challenge/png/i274.png
#   inflating: data/challenge/png/i275.png
#   inflating: data/challenge/png/i276.png
#   inflating: data/challenge/png/i277.png
#   inflating: data/challenge/png/i278.png
#   inflating: data/challenge/png/i279.png
#   inflating: data/challenge/png/i280.png
#   inflating: data/challenge/png/i281.png
#   inflating: data/challenge/png/i282.png
#   inflating: data/challenge/png/i283.png
#   inflating: data/challenge/png/i284.png
#   inflating: data/challenge/png/i285.png
#   inflating: data/challenge/png/i286.png
#   inflating: data/challenge/png/i287.png
#   inflating: data/challenge/png/i288.png
#   inflating: data/challenge/png/i289.png
#   inflating: data/challenge/png/i290.png
#   inflating: data/challenge/png/i291.png
#   inflating: data/challenge/png/i292.png
#   inflating: data/challenge/png/i293.png
#   inflating: data/challenge/png/i294.png
#   inflating: data/challenge/png/i295.png
#   inflating: data/challenge/png/i296.png
#   inflating: data/challenge/png/i297.png
#   inflating: data/challenge/png/i298.png
#   inflating: data/challenge/png/i299.png
#   inflating: data/challenge/png/i300.png
#    creating: data/mp4/
#   inflating: data/mp4/v001.mp4
#   inflating: data/mp4/v002.mp4
#   inflating: data/mp4/v003.mp4
#   inflating: data/mp4/v004.mp4
#   inflating: data/mp4/v005.mp4
#   inflating: data/mp4/v006.mp4
#   inflating: data/mp4/v007.mp4
#   inflating: data/mp4/v008.mp4
#   inflating: data/mp4/v009.mp4
#   inflating: data/mp4/v010.mp4
#   inflating: data/mp4/v011.mp4
#   inflating: data/mp4/v012.mp4
#   inflating: data/mp4/v013.mp4
#   inflating: data/mp4/v014.mp4
#   inflating: data/mp4/v015.mp4
#   inflating: data/mp4/v016.mp4
#   inflating: data/mp4/v017.mp4
#   inflating: data/mp4/v018.mp4
#   inflating: data/mp4/v019.mp4
#   inflating: data/mp4/v020.mp4
#   inflating: data/mp4/v021.mp4
#   inflating: data/mp4/v022.mp4
#   inflating: data/mp4/v023.mp4
#   inflating: data/mp4/v024.mp4
#   inflating: data/mp4/v025.mp4
#   inflating: data/mp4/v026.mp4
#   inflating: data/mp4/v027.mp4
#   inflating: data/mp4/v028.mp4
#   inflating: data/mp4/v029.mp4
#   inflating: data/mp4/v030.mp4
#   inflating: data/mp4/v031.mp4
#   inflating: data/mp4/v032.mp4
#   inflating: data/mp4/v033.mp4
#   inflating: data/mp4/v034.mp4
#   inflating: data/mp4/v035.mp4
#   inflating: data/mp4/v036.mp4
#   inflating: data/mp4/v037.mp4
#   inflating: data/mp4/v038.mp4
#   inflating: data/mp4/v039.mp4
#   inflating: data/mp4/v040.mp4
#   inflating: data/mp4/v041.mp4
#   inflating: data/mp4/v042.mp4
#   inflating: data/mp4/v043.mp4
#   inflating: data/mp4/v044.mp4
#   inflating: data/mp4/v045.mp4
#   inflating: data/mp4/v046.mp4
#   inflating: data/mp4/v047.mp4
#   inflating: data/mp4/v048.mp4
#   inflating: data/mp4/v049.mp4
#   inflating: data/mp4/v050.mp4
#   inflating: data/mp4/v051.mp4
#   inflating: data/mp4/v052.mp4
#   inflating: data/mp4/v053.mp4
#   inflating: data/mp4/v054.mp4
#   inflating: data/mp4/v055.mp4
#   inflating: data/mp4/v056.mp4
#   inflating: data/mp4/v057.mp4
#   inflating: data/mp4/v058.mp4
#   inflating: data/mp4/v059.mp4
#   inflating: data/mp4/v060.mp4
#   inflating: data/mp4/v061.mp4
#   inflating: data/mp4/v062.mp4
#   inflating: data/mp4/v063.mp4
#   inflating: data/mp4/v064.mp4
#   inflating: data/mp4/v065.mp4
#   inflating: data/mp4/v066.mp4
#   inflating: data/mp4/v067.mp4
#   inflating: data/mp4/v068.mp4
#   inflating: data/mp4/v069.mp4
#   inflating: data/mp4/v070.mp4
#   inflating: data/mp4/v071.mp4
#   inflating: data/mp4/v072.mp4
#   inflating: data/mp4/v073.mp4
#   inflating: data/mp4/v074.mp4
#   inflating: data/mp4/v075.mp4
#   inflating: data/mp4/v076.mp4
#   inflating: data/mp4/v077.mp4
#   inflating: data/mp4/v078.mp4
#   inflating: data/mp4/v079.mp4
#   inflating: data/mp4/v080.mp4
#   inflating: data/mp4/v081.mp4
#   inflating: data/mp4/v082.mp4
#   inflating: data/mp4/v083.mp4
#   inflating: data/mp4/v084.mp4
#   inflating: data/mp4/v085.mp4
#   inflating: data/mp4/v086.mp4
#   inflating: data/mp4/v087.mp4
#   inflating: data/mp4/v088.mp4
#   inflating: data/mp4/v089.mp4
#   inflating: data/mp4/v090.mp4
#   inflating: data/mp4/v091.mp4
#   inflating: data/mp4/v092.mp4
#   inflating: data/mp4/v093.mp4
#   inflating: data/mp4/v094.mp4
#   inflating: data/mp4/v095.mp4
#   inflating: data/mp4/v096.mp4
#   inflating: data/mp4/v097.mp4
#   inflating: data/mp4/v098.mp4
#   inflating: data/mp4/v099.mp4
#   inflating: data/mp4/v100.mp4
#    creating: data/test/
#    creating: data/test/jpeg/
#   inflating: data/test/jpeg/i001.jpeg
#   inflating: data/test/jpeg/i002.jpeg
#   inflating: data/test/jpeg/i003.jpeg
#   inflating: data/test/jpeg/i004.jpeg
#   inflating: data/test/jpeg/i005.jpeg
#   inflating: data/test/jpeg/i006.jpeg
#   inflating: data/test/jpeg/i007.jpeg
#   inflating: data/test/jpeg/i008.jpeg
#   inflating: data/test/jpeg/i009.jpeg
#   inflating: data/test/jpeg/i010.jpeg
#   inflating: data/test/jpeg/i011.jpeg
#   inflating: data/test/jpeg/i012.jpeg
#   inflating: data/test/jpeg/i013.jpeg
#   inflating: data/test/jpeg/i014.jpeg
#   inflating: data/test/jpeg/i015.jpeg
#   inflating: data/test/jpeg/i016.jpeg
#   inflating: data/test/jpeg/i017.jpeg
#   inflating: data/test/jpeg/i018.jpeg
#   inflating: data/test/jpeg/i019.jpeg
#   inflating: data/test/jpeg/i020.jpeg
#   inflating: data/test/jpeg/i021.jpeg
#   inflating: data/test/jpeg/i022.jpeg
#   inflating: data/test/jpeg/i023.jpeg
#   inflating: data/test/jpeg/i024.jpeg
#   inflating: data/test/jpeg/i025.jpeg
#   inflating: data/test/jpeg/i026.jpeg
#   inflating: data/test/jpeg/i027.jpeg
#   inflating: data/test/jpeg/i028.jpeg
#   inflating: data/test/jpeg/i029.jpeg
#   inflating: data/test/jpeg/i030.jpeg
#   inflating: data/test/jpeg/i031.jpeg
#   inflating: data/test/jpeg/i032.jpeg
#   inflating: data/test/jpeg/i033.jpeg
#   inflating: data/test/jpeg/i034.jpeg
#   inflating: data/test/jpeg/i035.jpeg
#   inflating: data/test/jpeg/i036.jpeg
#   inflating: data/test/jpeg/i037.jpeg
#   inflating: data/test/jpeg/i038.jpeg
#   inflating: data/test/jpeg/i039.jpeg
#   inflating: data/test/jpeg/i040.jpeg
#   inflating: data/test/jpeg/i041.jpeg
#   inflating: data/test/jpeg/i042.jpeg
#   inflating: data/test/jpeg/i043.jpeg
#   inflating: data/test/jpeg/i044.jpeg
#   inflating: data/test/jpeg/i045.jpeg
#   inflating: data/test/jpeg/i046.jpeg
#   inflating: data/test/jpeg/i047.jpeg
#   inflating: data/test/jpeg/i048.jpeg
#   inflating: data/test/jpeg/i049.jpeg
#   inflating: data/test/jpeg/i050.jpeg
#   inflating: data/test/jpeg/i051.jpeg
#   inflating: data/test/jpeg/i052.jpeg
#   inflating: data/test/jpeg/i053.jpeg
#   inflating: data/test/jpeg/i054.jpeg
#   inflating: data/test/jpeg/i055.jpeg
#   inflating: data/test/jpeg/i056.jpeg
#   inflating: data/test/jpeg/i057.jpeg
#   inflating: data/test/jpeg/i058.jpeg
#   inflating: data/test/jpeg/i059.jpeg
#   inflating: data/test/jpeg/i060.jpeg
#   inflating: data/test/jpeg/i061.jpeg
#   inflating: data/test/jpeg/i062.jpeg
#   inflating: data/test/jpeg/i063.jpeg
#   inflating: data/test/jpeg/i064.jpeg
#   inflating: data/test/jpeg/i065.jpeg
#   inflating: data/test/jpeg/i066.jpeg
#   inflating: data/test/jpeg/i067.jpeg
#   inflating: data/test/jpeg/i068.jpeg
#   inflating: data/test/jpeg/i069.jpeg
#   inflating: data/test/jpeg/i070.jpeg
#   inflating: data/test/jpeg/i071.jpeg
#   inflating: data/test/jpeg/i072.jpeg
#   inflating: data/test/jpeg/i073.jpeg
#   inflating: data/test/jpeg/i074.jpeg
#   inflating: data/test/jpeg/i075.jpeg
#   inflating: data/test/jpeg/i076.jpeg
#   inflating: data/test/jpeg/i077.jpeg
#   inflating: data/test/jpeg/i078.jpeg
#   inflating: data/test/jpeg/i079.jpeg
#   inflating: data/test/jpeg/i080.jpeg
#   inflating: data/test/jpeg/i081.jpeg
#   inflating: data/test/jpeg/i082.jpeg
#   inflating: data/test/jpeg/i083.jpeg
#   inflating: data/test/jpeg/i084.jpeg
#   inflating: data/test/jpeg/i085.jpeg
#   inflating: data/test/jpeg/i086.jpeg
#   inflating: data/test/jpeg/i087.jpeg
#   inflating: data/test/jpeg/i088.jpeg
#   inflating: data/test/jpeg/i089.jpeg
#   inflating: data/test/jpeg/i090.jpeg
#   inflating: data/test/jpeg/i091.jpeg
#   inflating: data/test/jpeg/i092.jpeg
#   inflating: data/test/jpeg/i093.jpeg
#   inflating: data/test/jpeg/i094.jpeg
#   inflating: data/test/jpeg/i095.jpeg
#   inflating: data/test/jpeg/i096.jpeg
#   inflating: data/test/jpeg/i097.jpeg
#   inflating: data/test/jpeg/i098.jpeg
#   inflating: data/test/jpeg/i099.jpeg
#   inflating: data/test/jpeg/i100.jpeg
#   inflating: data/test/jpeg/i101.jpeg
#   inflating: data/test/jpeg/i102.jpeg
#   inflating: data/test/jpeg/i103.jpeg
#   inflating: data/test/jpeg/i104.jpeg
#   inflating: data/test/jpeg/i105.jpeg
#   inflating: data/test/jpeg/i106.jpeg
#   inflating: data/test/jpeg/i107.jpeg
#   inflating: data/test/jpeg/i108.jpeg
#   inflating: data/test/jpeg/i109.jpeg
#   inflating: data/test/jpeg/i110.jpeg
#   inflating: data/test/jpeg/i111.jpeg
#   inflating: data/test/jpeg/i112.jpeg
#   inflating: data/test/jpeg/i113.jpeg
#   inflating: data/test/jpeg/i114.jpeg
#   inflating: data/test/jpeg/i115.jpeg
#   inflating: data/test/jpeg/i116.jpeg
#   inflating: data/test/jpeg/i117.jpeg
#   inflating: data/test/jpeg/i118.jpeg
#   inflating: data/test/jpeg/i119.jpeg
#   inflating: data/test/jpeg/i120.jpeg
#   inflating: data/test/jpeg/i121.jpeg
#   inflating: data/test/jpeg/i122.jpeg
#   inflating: data/test/jpeg/i123.jpeg
#   inflating: data/test/jpeg/i124.jpeg
#   inflating: data/test/jpeg/i125.jpeg
#   inflating: data/test/jpeg/i126.jpeg
#   inflating: data/test/jpeg/i127.jpeg
#   inflating: data/test/jpeg/i128.jpeg
#   inflating: data/test/jpeg/i129.jpeg
#   inflating: data/test/jpeg/i130.jpeg
#   inflating: data/test/jpeg/i131.jpeg
#   inflating: data/test/jpeg/i132.jpeg
#   inflating: data/test/jpeg/i133.jpeg
#   inflating: data/test/jpeg/i134.jpeg
#   inflating: data/test/jpeg/i135.jpeg
#   inflating: data/test/jpeg/i136.jpeg
#   inflating: data/test/jpeg/i137.jpeg
#   inflating: data/test/jpeg/i138.jpeg
#   inflating: data/test/jpeg/i139.jpeg
#   inflating: data/test/jpeg/i140.jpeg
#   inflating: data/test/jpeg/i141.jpeg
#   inflating: data/test/jpeg/i142.jpeg
#   inflating: data/test/jpeg/i143.jpeg
#   inflating: data/test/jpeg/i144.jpeg
#   inflating: data/test/jpeg/i145.jpeg
#   inflating: data/test/jpeg/i146.jpeg
#   inflating: data/test/jpeg/i147.jpeg
#   inflating: data/test/jpeg/i148.jpeg
#   inflating: data/test/jpeg/i149.jpeg
#   inflating: data/test/jpeg/i150.jpeg
#   inflating: data/test/jpeg/i151.jpeg
#   inflating: data/test/jpeg/i152.jpeg
#   inflating: data/test/jpeg/i153.jpeg
#   inflating: data/test/jpeg/i154.jpeg
#   inflating: data/test/jpeg/i155.jpeg
#   inflating: data/test/jpeg/i156.jpeg
#   inflating: data/test/jpeg/i157.jpeg
#   inflating: data/test/jpeg/i158.jpeg
#   inflating: data/test/jpeg/i159.jpeg
#   inflating: data/test/jpeg/i160.jpeg
#   inflating: data/test/jpeg/i161.jpeg
#   inflating: data/test/jpeg/i162.jpeg
#   inflating: data/test/jpeg/i163.jpeg
#   inflating: data/test/jpeg/i164.jpeg
#   inflating: data/test/jpeg/i165.jpeg
#   inflating: data/test/jpeg/i166.jpeg
#   inflating: data/test/jpeg/i167.jpeg
#   inflating: data/test/jpeg/i168.jpeg
#   inflating: data/test/jpeg/i169.jpeg
#   inflating: data/test/jpeg/i170.jpeg
#   inflating: data/test/jpeg/i171.jpeg
#   inflating: data/test/jpeg/i172.jpeg
#   inflating: data/test/jpeg/i173.jpeg
#   inflating: data/test/jpeg/i174.jpeg
#   inflating: data/test/jpeg/i175.jpeg
#   inflating: data/test/jpeg/i176.jpeg
#   inflating: data/test/jpeg/i177.jpeg
#   inflating: data/test/jpeg/i178.jpeg
#   inflating: data/test/jpeg/i179.jpeg
#   inflating: data/test/jpeg/i180.jpeg
#   inflating: data/test/jpeg/i181.jpeg
#   inflating: data/test/jpeg/i182.jpeg
#   inflating: data/test/jpeg/i183.jpeg
#   inflating: data/test/jpeg/i184.jpeg
#   inflating: data/test/jpeg/i185.jpeg
#   inflating: data/test/jpeg/i186.jpeg
#   inflating: data/test/jpeg/i187.jpeg
#   inflating: data/test/jpeg/i188.jpeg
#   inflating: data/test/jpeg/i189.jpeg
#   inflating: data/test/jpeg/i190.jpeg
#   inflating: data/test/jpeg/i191.jpeg
#   inflating: data/test/jpeg/i192.jpeg
#   inflating: data/test/jpeg/i193.jpeg
#   inflating: data/test/jpeg/i194.jpeg
#   inflating: data/test/jpeg/i195.jpeg
#   inflating: data/test/jpeg/i196.jpeg
#   inflating: data/test/jpeg/i197.jpeg
#   inflating: data/test/jpeg/i198.jpeg
#   inflating: data/test/jpeg/i199.jpeg
#   inflating: data/test/jpeg/i200.jpeg
#   inflating: data/test/jpeg/i201.jpeg
#   inflating: data/test/jpeg/i202.jpeg
#   inflating: data/test/jpeg/i203.jpeg
#   inflating: data/test/jpeg/i204.jpeg
#   inflating: data/test/jpeg/i205.jpeg
#   inflating: data/test/jpeg/i206.jpeg
#   inflating: data/test/jpeg/i207.jpeg
#   inflating: data/test/jpeg/i208.jpeg
#   inflating: data/test/jpeg/i209.jpeg
#   inflating: data/test/jpeg/i210.jpeg
#   inflating: data/test/jpeg/i211.jpeg
#   inflating: data/test/jpeg/i212.jpeg
#   inflating: data/test/jpeg/i213.jpeg
#   inflating: data/test/jpeg/i214.jpeg
#   inflating: data/test/jpeg/i215.jpeg
#   inflating: data/test/jpeg/i216.jpeg
#   inflating: data/test/jpeg/i217.jpeg
#   inflating: data/test/jpeg/i218.jpeg
#   inflating: data/test/jpeg/i219.jpeg
#   inflating: data/test/jpeg/i220.jpeg
#   inflating: data/test/jpeg/i221.jpeg
#   inflating: data/test/jpeg/i222.jpeg
#   inflating: data/test/jpeg/i223.jpeg
#   inflating: data/test/jpeg/i224.jpeg
#   inflating: data/test/jpeg/i225.jpeg
#   inflating: data/test/jpeg/i226.jpeg
#   inflating: data/test/jpeg/i227.jpeg
#   inflating: data/test/jpeg/i228.jpeg
#   inflating: data/test/jpeg/i229.jpeg
#   inflating: data/test/jpeg/i230.jpeg
#   inflating: data/test/jpeg/i231.jpeg
#   inflating: data/test/jpeg/i232.jpeg
#   inflating: data/test/jpeg/i233.jpeg
#   inflating: data/test/jpeg/i234.jpeg
#   inflating: data/test/jpeg/i235.jpeg
#   inflating: data/test/jpeg/i236.jpeg
#   inflating: data/test/jpeg/i237.jpeg
#   inflating: data/test/jpeg/i238.jpeg
#   inflating: data/test/jpeg/i239.jpeg
#   inflating: data/test/jpeg/i240.jpeg
#   inflating: data/test/jpeg/i241.jpeg
#   inflating: data/test/jpeg/i242.jpeg
#   inflating: data/test/jpeg/i243.jpeg
#   inflating: data/test/jpeg/i244.jpeg
#   inflating: data/test/jpeg/i245.jpeg
#   inflating: data/test/jpeg/i246.jpeg
#   inflating: data/test/jpeg/i247.jpeg
#   inflating: data/test/jpeg/i248.jpeg
#   inflating: data/test/jpeg/i249.jpeg
#   inflating: data/test/jpeg/i250.jpeg
#   inflating: data/test/jpeg/i251.jpeg
#   inflating: data/test/jpeg/i252.jpeg
#   inflating: data/test/jpeg/i253.jpeg
#   inflating: data/test/jpeg/i254.jpeg
#   inflating: data/test/jpeg/i255.jpeg
#   inflating: data/test/jpeg/i256.jpeg
#   inflating: data/test/jpeg/i257.jpeg
#   inflating: data/test/jpeg/i258.jpeg
#   inflating: data/test/jpeg/i259.jpeg
#   inflating: data/test/jpeg/i260.jpeg
#   inflating: data/test/jpeg/i261.jpeg
#   inflating: data/test/jpeg/i262.jpeg
#   inflating: data/test/jpeg/i263.jpeg
#   inflating: data/test/jpeg/i264.jpeg
#   inflating: data/test/jpeg/i265.jpeg
#   inflating: data/test/jpeg/i266.jpeg
#   inflating: data/test/jpeg/i267.jpeg
#   inflating: data/test/jpeg/i268.jpeg
#   inflating: data/test/jpeg/i269.jpeg
#   inflating: data/test/jpeg/i270.jpeg
#   inflating: data/test/jpeg/i271.jpeg
#   inflating: data/test/jpeg/i272.jpeg
#   inflating: data/test/jpeg/i273.jpeg
#   inflating: data/test/jpeg/i274.jpeg
#   inflating: data/test/jpeg/i275.jpeg
#   inflating: data/test/jpeg/i276.jpeg
#   inflating: data/test/jpeg/i277.jpeg
#   inflating: data/test/jpeg/i278.jpeg
#   inflating: data/test/jpeg/i279.jpeg
#   inflating: data/test/jpeg/i280.jpeg
#   inflating: data/test/jpeg/i281.jpeg
#   inflating: data/test/jpeg/i282.jpeg
#   inflating: data/test/jpeg/i283.jpeg
#   inflating: data/test/jpeg/i284.jpeg
#   inflating: data/test/jpeg/i285.jpeg
#   inflating: data/test/jpeg/i286.jpeg
#   inflating: data/test/jpeg/i287.jpeg
#   inflating: data/test/jpeg/i288.jpeg
#   inflating: data/test/jpeg/i289.jpeg
#   inflating: data/test/jpeg/i290.jpeg
#   inflating: data/test/jpeg/i291.jpeg
#   inflating: data/test/jpeg/i292.jpeg
#   inflating: data/test/jpeg/i293.jpeg
#   inflating: data/test/jpeg/i294.jpeg
#   inflating: data/test/jpeg/i295.jpeg
#   inflating: data/test/jpeg/i296.jpeg
#   inflating: data/test/jpeg/i297.jpeg
#   inflating: data/test/jpeg/i298.jpeg
#   inflating: data/test/jpeg/i299.jpeg
#   inflating: data/test/jpeg/i300.jpeg
#    creating: data/test/png/
#   inflating: data/test/png/i001.png
#   inflating: data/test/png/i002.png
#   inflating: data/test/png/i003.png
#   inflating: data/test/png/i004.png
#   inflating: data/test/png/i005.png
#   inflating: data/test/png/i006.png
#   inflating: data/test/png/i007.png
#   inflating: data/test/png/i008.png
#   inflating: data/test/png/i009.png
#   inflating: data/test/png/i010.png
#   inflating: data/test/png/i011.png
#   inflating: data/test/png/i012.png
#   inflating: data/test/png/i013.png
#   inflating: data/test/png/i014.png
#   inflating: data/test/png/i015.png
#   inflating: data/test/png/i016.png
#   inflating: data/test/png/i017.png
#   inflating: data/test/png/i018.png
#   inflating: data/test/png/i019.png
#   inflating: data/test/png/i020.png
#   inflating: data/test/png/i021.png
#   inflating: data/test/png/i022.png
#   inflating: data/test/png/i023.png
#   inflating: data/test/png/i024.png
#   inflating: data/test/png/i025.png
#   inflating: data/test/png/i026.png
#   inflating: data/test/png/i027.png
#   inflating: data/test/png/i028.png
#   inflating: data/test/png/i029.png
#   inflating: data/test/png/i030.png
#   inflating: data/test/png/i031.png
#   inflating: data/test/png/i032.png
#   inflating: data/test/png/i033.png
#   inflating: data/test/png/i034.png
#   inflating: data/test/png/i035.png
#   inflating: data/test/png/i036.png
#   inflating: data/test/png/i037.png
#   inflating: data/test/png/i038.png
#   inflating: data/test/png/i039.png
#   inflating: data/test/png/i040.png
#   inflating: data/test/png/i041.png
#   inflating: data/test/png/i042.png
#   inflating: data/test/png/i043.png
#   inflating: data/test/png/i044.png
#   inflating: data/test/png/i045.png
#   inflating: data/test/png/i046.png
#   inflating: data/test/png/i047.png
#   inflating: data/test/png/i048.png
#   inflating: data/test/png/i049.png
#   inflating: data/test/png/i050.png
#   inflating: data/test/png/i051.png
#   inflating: data/test/png/i052.png
#   inflating: data/test/png/i053.png
#   inflating: data/test/png/i054.png
#   inflating: data/test/png/i055.png
#   inflating: data/test/png/i056.png
#   inflating: data/test/png/i057.png
#   inflating: data/test/png/i058.png
#   inflating: data/test/png/i059.png
#   inflating: data/test/png/i060.png
#   inflating: data/test/png/i061.png
#   inflating: data/test/png/i062.png
#   inflating: data/test/png/i063.png
#   inflating: data/test/png/i064.png
#   inflating: data/test/png/i065.png
#   inflating: data/test/png/i066.png
#   inflating: data/test/png/i067.png
#   inflating: data/test/png/i068.png
#   inflating: data/test/png/i069.png
#   inflating: data/test/png/i070.png
#   inflating: data/test/png/i071.png
#   inflating: data/test/png/i072.png
#   inflating: data/test/png/i073.png
#   inflating: data/test/png/i074.png
#   inflating: data/test/png/i075.png
#   inflating: data/test/png/i076.png
#   inflating: data/test/png/i077.png
#   inflating: data/test/png/i078.png
#   inflating: data/test/png/i079.png
#   inflating: data/test/png/i080.png
#   inflating: data/test/png/i081.png
#   inflating: data/test/png/i082.png
#   inflating: data/test/png/i083.png
#   inflating: data/test/png/i084.png
#   inflating: data/test/png/i085.png
#   inflating: data/test/png/i086.png
#   inflating: data/test/png/i087.png
#   inflating: data/test/png/i088.png
#   inflating: data/test/png/i089.png
#   inflating: data/test/png/i090.png
#   inflating: data/test/png/i091.png
#   inflating: data/test/png/i092.png
#   inflating: data/test/png/i093.png
#   inflating: data/test/png/i094.png
#   inflating: data/test/png/i095.png
#   inflating: data/test/png/i096.png
#   inflating: data/test/png/i097.png
#   inflating: data/test/png/i098.png
#   inflating: data/test/png/i099.png
#   inflating: data/test/png/i100.png
#   inflating: data/test/png/i101.png
#   inflating: data/test/png/i102.png
#   inflating: data/test/png/i103.png
#   inflating: data/test/png/i104.png
#   inflating: data/test/png/i105.png
#   inflating: data/test/png/i106.png
#   inflating: data/test/png/i107.png
#   inflating: data/test/png/i108.png
#   inflating: data/test/png/i109.png
#   inflating: data/test/png/i110.png
#   inflating: data/test/png/i111.png
#   inflating: data/test/png/i112.png
#   inflating: data/test/png/i113.png
#   inflating: data/test/png/i114.png
#   inflating: data/test/png/i115.png
#   inflating: data/test/png/i116.png
#   inflating: data/test/png/i117.png
#   inflating: data/test/png/i118.png
#   inflating: data/test/png/i119.png
#   inflating: data/test/png/i120.png
#   inflating: data/test/png/i121.png
#   inflating: data/test/png/i122.png
#   inflating: data/test/png/i123.png
#   inflating: data/test/png/i124.png
#   inflating: data/test/png/i125.png
#   inflating: data/test/png/i126.png
#   inflating: data/test/png/i127.png
#   inflating: data/test/png/i128.png
#   inflating: data/test/png/i129.png
#   inflating: data/test/png/i130.png
#   inflating: data/test/png/i131.png
#   inflating: data/test/png/i132.png
#   inflating: data/test/png/i133.png
#   inflating: data/test/png/i134.png
#   inflating: data/test/png/i135.png
#   inflating: data/test/png/i136.png
#   inflating: data/test/png/i137.png
#   inflating: data/test/png/i138.png
#   inflating: data/test/png/i139.png
#   inflating: data/test/png/i140.png
#   inflating: data/test/png/i141.png
#   inflating: data/test/png/i142.png
#   inflating: data/test/png/i143.png
#   inflating: data/test/png/i144.png
#   inflating: data/test/png/i145.png
#   inflating: data/test/png/i146.png
#   inflating: data/test/png/i147.png
#   inflating: data/test/png/i148.png
#   inflating: data/test/png/i149.png
#   inflating: data/test/png/i150.png
#   inflating: data/test/png/i151.png
#   inflating: data/test/png/i152.png
#   inflating: data/test/png/i153.png
#   inflating: data/test/png/i154.png
#   inflating: data/test/png/i155.png
#   inflating: data/test/png/i156.png
#   inflating: data/test/png/i157.png
#   inflating: data/test/png/i158.png
#   inflating: data/test/png/i159.png
#   inflating: data/test/png/i160.png
#   inflating: data/test/png/i161.png
#   inflating: data/test/png/i162.png
#   inflating: data/test/png/i163.png
#   inflating: data/test/png/i164.png
#   inflating: data/test/png/i165.png
#   inflating: data/test/png/i166.png
#   inflating: data/test/png/i167.png
#   inflating: data/test/png/i168.png
#   inflating: data/test/png/i169.png
#   inflating: data/test/png/i170.png
#   inflating: data/test/png/i171.png
#   inflating: data/test/png/i172.png
#   inflating: data/test/png/i173.png
#   inflating: data/test/png/i174.png
#   inflating: data/test/png/i175.png
#   inflating: data/test/png/i176.png
#   inflating: data/test/png/i177.png
#   inflating: data/test/png/i178.png
#   inflating: data/test/png/i179.png
#   inflating: data/test/png/i180.png
#   inflating: data/test/png/i181.png
#   inflating: data/test/png/i182.png
#   inflating: data/test/png/i183.png
#   inflating: data/test/png/i184.png
#   inflating: data/test/png/i185.png
#   inflating: data/test/png/i186.png
#   inflating: data/test/png/i187.png
#   inflating: data/test/png/i188.png
#   inflating: data/test/png/i189.png
#   inflating: data/test/png/i190.png
#   inflating: data/test/png/i191.png
#   inflating: data/test/png/i192.png
#   inflating: data/test/png/i193.png
#   inflating: data/test/png/i194.png
#   inflating: data/test/png/i195.png
#   inflating: data/test/png/i196.png
#   inflating: data/test/png/i197.png
#   inflating: data/test/png/i198.png
#   inflating: data/test/png/i199.png
#   inflating: data/test/png/i200.png
#   inflating: data/test/png/i201.png
#   inflating: data/test/png/i202.png
#   inflating: data/test/png/i203.png
#   inflating: data/test/png/i204.png
#   inflating: data/test/png/i205.png
#   inflating: data/test/png/i206.png
#   inflating: data/test/png/i207.png
#   inflating: data/test/png/i208.png
#   inflating: data/test/png/i209.png
#   inflating: data/test/png/i210.png
#   inflating: data/test/png/i211.png
#   inflating: data/test/png/i212.png
#   inflating: data/test/png/i213.png
#   inflating: data/test/png/i214.png
#   inflating: data/test/png/i215.png
#   inflating: data/test/png/i216.png
#   inflating: data/test/png/i217.png
#   inflating: data/test/png/i218.png
#   inflating: data/test/png/i219.png
#   inflating: data/test/png/i220.png
#   inflating: data/test/png/i221.png
#   inflating: data/test/png/i222.png
#   inflating: data/test/png/i223.png
#   inflating: data/test/png/i224.png
#   inflating: data/test/png/i225.png
#   inflating: data/test/png/i226.png
#   inflating: data/test/png/i227.png
#   inflating: data/test/png/i228.png
#   inflating: data/test/png/i229.png
#   inflating: data/test/png/i230.png
#   inflating: data/test/png/i231.png
#   inflating: data/test/png/i232.png
#   inflating: data/test/png/i233.png
#   inflating: data/test/png/i234.png
#   inflating: data/test/png/i235.png
#   inflating: data/test/png/i236.png
#   inflating: data/test/png/i237.png
#   inflating: data/test/png/i238.png
#   inflating: data/test/png/i239.png
#   inflating: data/test/png/i240.png
#   inflating: data/test/png/i241.png
#   inflating: data/test/png/i242.png
#   inflating: data/test/png/i243.png
#   inflating: data/test/png/i244.png
#   inflating: data/test/png/i245.png
#   inflating: data/test/png/i246.png
#   inflating: data/test/png/i247.png
#   inflating: data/test/png/i248.png
#   inflating: data/test/png/i249.png
#   inflating: data/test/png/i250.png
#   inflating: data/test/png/i251.png
#   inflating: data/test/png/i252.png
#   inflating: data/test/png/i253.png
#   inflating: data/test/png/i254.png
#   inflating: data/test/png/i255.png
#   inflating: data/test/png/i256.png
#   inflating: data/test/png/i257.png
#   inflating: data/test/png/i258.png
#   inflating: data/test/png/i259.png
#   inflating: data/test/png/i260.png
#   inflating: data/test/png/i261.png
#   inflating: data/test/png/i262.png
#   inflating: data/test/png/i263.png
#   inflating: data/test/png/i264.png
#   inflating: data/test/png/i265.png
#   inflating: data/test/png/i266.png
#   inflating: data/test/png/i267.png
#   inflating: data/test/png/i268.png
#   inflating: data/test/png/i269.png
#   inflating: data/test/png/i270.png
#   inflating: data/test/png/i271.png
#   inflating: data/test/png/i272.png
#   inflating: data/test/png/i273.png
#   inflating: data/test/png/i274.png
#   inflating: data/test/png/i275.png
#   inflating: data/test/png/i276.png
#   inflating: data/test/png/i277.png
#   inflating: data/test/png/i278.png
#   inflating: data/test/png/i279.png
#   inflating: data/test/png/i280.png
#   inflating: data/test/png/i281.png
#   inflating: data/test/png/i282.png
#   inflating: data/test/png/i283.png
#   inflating: data/test/png/i284.png
#   inflating: data/test/png/i285.png
#   inflating: data/test/png/i286.png
#   inflating: data/test/png/i287.png
#   inflating: data/test/png/i288.png
#   inflating: data/test/png/i289.png
#   inflating: data/test/png/i290.png
#   inflating: data/test/png/i291.png
#   inflating: data/test/png/i292.png
#   inflating: data/test/png/i293.png
#   inflating: data/test/png/i294.png
#   inflating: data/test/png/i295.png
#   inflating: data/test/png/i296.png
#   inflating: data/test/png/i297.png
#   inflating: data/test/png/i298.png
#   inflating: data/test/png/i299.png
#   inflating: data/test/png/i300.png
#   inflating: data/test/test_gt.csv
#    creating: results/

# %% [markdown]
# ## Data Exploration

# %%
import os
import pandas as pd
import cv2
import numpy as np
from tqdm import tqdm

# %%
os.listdir('data/test/')
# Out:
# ['test_gt.csv', 'jpeg', 'png']

# %%
test = pd.read_csv('data/test/test_gt.csv')
test.head()
# Out:
#   image video   minutage
# 0  i001  v001   1.750000
# 1  i002  v050  17.017000
# 2  i003   out        NaN
# 3  i004  v042  11.378033
# 4  i005  v063   5.338667

# %% [markdown]
# ## Q.2

# %% [markdown]
# ### Algorithme de Carol

# %%
# Load a video and store the histograms of trames according to target_fps frequence
def load_video(filename,target_fps,hist_bins=128,hist_range=[0,256]):
  cap = cv2.VideoCapture(f"data/mp4/{filename}")
  fps = cap.get(cv2.CAP_PROP_FPS)
  if target_fps is None:
    target_fps = fps
  i = 0
  assert(target_fps<=fps)
  interval = fps//target_fps
  list_hist = []
  # Look through the frames
  while(True):
    ret, frame = cap.read()
    if ret:
      if i%interval == 0:
        hist = np.histogram(frame.ravel(),bins=hist_bins,range=hist_range)
        list_hist.append(hist[0])
      i+=1
    if cv2.waitKey(1) & 0xFF == ord('q') or ret==False :
        cap.release()
        cv2.destroyAllWindows()
        break
  time_array = np.arange(len(list_hist))/target_fps
  return np.array(list_hist), time_array

# %%
# Build histograms dict
video_dic = dict()
for filename in tqdm(os.listdir('data/mp4')):
  video_dic[filename[:-4]] = load_video(filename,target_fps=1,hist_bins=128,hist_range=[0,256])
# Out:
# 100%|██████████| 100/100 [03:56<00:00,  2.36s/it]

# %%
# Function that returns the closest video and time
def get_video(image_filename,out_threshold=np.inf):
  img = cv2.imread(f'data/test/{image_filename}')
  img_hist = np.histogram(img,128,[0,256])[0]
  global_min = np.inf
  for video in video_dic:
    local_min = np.linalg.norm(np.array(video_dic[video][0])-img_hist,axis=1).min()
    if local_min < global_min:
      global_min = local_min
      best_video = video
      best_index = np.linalg.norm(np.array(video_dic[video][0])-img_hist,axis=1).argmin()
      best_time = video_dic[best_video][1][best_index]
      if global_min==0:
        return best_video,best_index
  if global_min>out_threshold:
    return None,None
  else:
    return best_video,best_time

get_video('jpeg/i045.jpeg')
# Out:
# ('v054', 3.0)

# %%
# Loads test dataset
test=pd.read_csv('/content/data/test/test_gt.csv')

# %%
# Creates prediction on png
res_png = pd.DataFrame()
video_pred=[]
minutage_pred=[]
for image in tqdm(test.image):
  image_filename='png/'+image+'.png'
  video,minutage = get_video(image_filename)
  video_pred.append(video)
  minutage_pred.append(minutage)
res_png['image']=test.image
res_png['video_pred']=video_pred
res_png['minutage_pred']=minutage_pred
# Stores results in file
res_png.to_csv("results/test_png.csv",index=False)
# Out:
# 100%|██████████| 300/300 [00:18<00:00, 15.93it/s]

# %%
# Creates prediction on jpeg
res_jpeg = pd.DataFrame()
video_pred=[]
minutage_pred=[]
for image in tqdm(test.image):
  image_filename='jpeg/'+image+'.jpeg'
  video,minutage = get_video(image_filename)
  video_pred.append(video)
  minutage_pred.append(minutage)
res_jpeg['image']=test.image
res_jpeg['video_pred']=video_pred
res_jpeg['minutage_pred']=minutage_pred
# Stores results in file
res_jpeg.to_csv("results/test_jpeg.csv",index=False)
# Out:
# 100%|██████████| 300/300 [00:15<00:00, 19.52it/s]

# %%
# !python src/evaluate.py --file=results/test_png.csv --file_gt=data/test/test_gt.csv
# Out:
# Taux de bonnes réponses : 78.0% (234/300)
# Ecart temporel moyen : 0.58 sec

# %%
# !python src/evaluate.py --file=results/test_jpeg.csv --file_gt=data/test/test_gt.csv
# Out:
# Taux de bonnes réponses : 67.7% (203/300)
# Ecart temporel moyen : 2.59 sec

# %%
# Upper bound sur la précision
(test.video!='out').mean()
# Out:
# 0.7866666666666666

# %% [markdown]
# ## Q3.

# %% [markdown]
# ### Méthode avancée

# %%
# !pip install torchmetrics
# !pip install annoy
# !pip install decord
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.1.0+cu118)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.10.0 torchmetrics-1.2.0
# Collecting annoy
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.3-cp310-cp310-linux_x86_64.whl size=552451 sha256=5d25531a35ee70564f0829f2ac288fc125e08691864d5800d4120a5ab89ab2c5
#   Stored in directory: /root/.cache/pip/wheels/64/8a/da/f714bcf46c5efdcfcac0559e63370c21abe961c48e3992465a
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.3
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from decord) (1.23.5)
# Installing collected packages: decord
# Successfully installed decord-0.6.0

# %%
import os
from PIL import Image
import torch
import torch.nn as nn
from torchvision import models, transforms
from torchmetrics.image import StructuralSimilarityIndexMeasure
from torchmetrics.regression import MeanSquaredError
from annoy import AnnoyIndex
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from decord import VideoReader
from decord import cpu
import matplotlib.pyplot as plt

MP4_DIR = "data/mp4/"

model_transform = transforms.Compose([
    transforms.ToPILImage("RGB"),
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

to_gray_scale_transform = transforms.Compose([
    transforms.Grayscale()
])

"""# Find all images"""
if torch.cuda.is_available():
    dev = "cuda:0"
else:
    dev = "cpu"
device = torch.device(dev)

# Charge le réseau préentrainé
resnet50_weights = models.ResNet50_Weights.IMAGENET1K_V1

ResNet50_model = models.resnet50(weights=resnet50_weights)

ResNet50_model.fc = nn.Identity()

# Utilise si possible le GPU
ResNet50_model.to(device)

# # Pour ne pas entraîner le modèle
ResNet50_model.eval()

files_dict = {}

# Pour analyser des photos de même taille


"""Trouver des images similaires"""

def generate_dict():
    video_files_names: list = os.listdir(MP4_DIR)
    temp_frames = {}
    id = 0
    # We use a global index that indentify a frame in all the videos
    for video_name in video_files_names:
        path = os.path.join(MP4_DIR, video_name)
        vr = VideoReader(path)
        total_frames = len(vr)
        fps = vr.get_avg_fps()
        for frame in range(total_frames):
            temp_frames[id] = {
                "video": video_name,
                "path": path,
                "index": frame,
                "fps": fps,
                "total_frames": total_frames,
                "timestamp": frame / fps,
                "global_index": id,
            }
            id += 1
    return temp_frames

frames = generate_dict()

def video_process():
    resnet_annoy_index_20 = AnnoyIndex(2048, "angular")

    videos_files_names: list = os.listdir(MP4_DIR)

    frame_id = 0
    for video_index in tqdm(range(len(videos_files_names))):
        video_path = MP4_DIR + videos_files_names[video_index]
        vr = VideoReader(video_path, ctx=cpu(0))
        fps = vr.get_avg_fps()
        total_frames = len(vr)
        for frames_index in (range((int(total_frames)))):
            frame = vr[frames_index]

            input_tensor = model_transform(frame.asnumpy()).unsqueeze(0).to(device)
            if input_tensor.size()[1] == 3:
                resnet_output_tensor = ResNet50_model(input_tensor)
                resnet_out_np = resnet_output_tensor[0].data.cpu().numpy()

                files_dict[frame_id] = {
                    "video": videos_files_names[video_index],
                    "frame": frames_index,
                    "time": frames_index / fps}
                # Ajoute la représentation de la frame fournie par le modèle ResNet50 à l'index
                resnet_annoy_index_20.add_item(frame_id, resnet_out_np)
                frame_id += 1

    resnet_annoy_index_20.build(20)
    resnet_annoy_index_20.save("resnet_annoy_index_20.ann")


def cosine_similarity(tensor_hist_1, tensor_hist_2):
    return torch.dot(tensor_hist_1, tensor_hist_2) / (torch.norm(tensor_hist_1) * torch.norm(tensor_hist_2))


def show_plot(im1, im2, name, ratio=(12,16), cmap=None):
    fig, axs = plt.subplots(2, 1, figsize=ratio)
    axs[0].set_title("Original")
    axs[1].set_title("Predicted")
    if not cmap:
        axs[0].imshow(im1)
        axs[1].imshow(im2)
    else:
        axs[0].imshow(im1, cmap=cmap)
        axs[1].imshow(im2, cmap=cmap)
    plt.title(name)
    plt.show()

def test_dir(directory, csv_name):

    annoy_annex = AnnoyIndex(2048, "angular")
    annoy_annex.load("resnet_annoy_index_20.ann")

    image, video_pred, minutage_pred = [], [], []
    images_files = os.listdir(directory)

    n_bins = 25

    for image_file in tqdm(images_files, desc=csv_name):
        img = Image.open(directory + image_file)
        np_img = np.array(img)

        model_input_tensor = model_transform(np.array(img)).unsqueeze(0).to(device)

        tensor_original = torch.from_numpy(np_img).permute((2, 0, 1)).to(device).float()
        tensor_luminance_original = to_gray_scale_transform(tensor_original)[0]
        tensor_original_gauss1 = transforms.functional.gaussian_blur(tensor_luminance_original.unsqueeze(0), (9, 9),3).squeeze(0).to(device)
        tensor_original_gauss2 = transforms.functional.gaussian_blur(tensor_luminance_original.unsqueeze(0), (9, 9),6).squeeze(0).to(device)
        tensor_original_dif_gauss = torch.absolute(tensor_original_gauss1 - tensor_original_gauss2)
        tensor_original_dif_gauss = tensor_original_dif_gauss * 255 / torch.max(tensor_original_dif_gauss).item()
        hist_luminance_original = torch.histc(tensor_luminance_original, bins=n_bins)

        tensor_original_rgb = tensor_original.unbind(0)
        hist_red_original = torch.histc(tensor_original_rgb[0], bins=n_bins)
        hist_green_original = torch.histc(tensor_original_rgb[1], bins=n_bins)
        hist_blue_original = torch.histc(tensor_original_rgb[2], bins=n_bins)


        if model_input_tensor.size()[1] == 3:

            model_output_tensor = ResNet50_model(model_input_tensor)
            # Retrouve la trame la plus proche dans l'index Annoy
            voisin_proche = annoy_annex.get_nns_by_vector(model_output_tensor[0], 1)

            video_name = frames[voisin_proche[0]]["video"]
            video_frame = frames[voisin_proche[0]][("index")]
            video_timestamp = frames[voisin_proche[0]]["timestamp"]
            predicted_video = VideoReader(MP4_DIR + video_name)
            np_predicted = predicted_video[video_frame].asnumpy()
            tensor_predicted = torch.from_numpy(np_predicted).permute((2, 0, 1)).to(device).float()

            tensor_luminance_predicted = to_gray_scale_transform(tensor_predicted)[0].to(device)

            tensor_predicted_gauss1 = transforms.functional.gaussian_blur(tensor_luminance_predicted.unsqueeze(0), (9, 9),3).squeeze(0).to(device)
            tensor_predicted_gauss2 = transforms.functional.gaussian_blur(tensor_luminance_predicted.unsqueeze(0), (9, 9), 6).squeeze(0).to(device)
            tensor_predicted_dif_gauss = torch.absolute(tensor_predicted_gauss1-tensor_predicted_gauss2)
            tensor_predicted_dif_gauss = tensor_predicted_dif_gauss * 255/torch.max(tensor_predicted_dif_gauss).item()

            # unbind(0) seperate each channel of the image in three tensors R, G and B
            tensor_predicted_rgb = tensor_predicted.unbind(0)

            hist_luminance_predicted = torch.histc(tensor_luminance_predicted, bins=n_bins)
            # Cosine Similarity of luminance histogram
            cos_l = cosine_similarity(hist_luminance_original, hist_luminance_predicted).detach().cpu().item()

            hist_red_predicted = torch.histc(tensor_predicted_rgb[0], bins=n_bins)
            hist_green_predicted = torch.histc(tensor_predicted_rgb[1], bins=n_bins)
            hist_blue_predicted = torch.histc(tensor_predicted_rgb[2], bins=n_bins)

            # Cosine Similarity of r, g and b histograms
            cos_r = cosine_similarity(hist_red_original, hist_red_predicted)
            cos_g = cosine_similarity(hist_green_original, hist_green_predicted)
            cos_b = cosine_similarity(hist_blue_original, hist_blue_predicted)
            cos_rgb = torch.mean(torch.cat((cos_r.unsqueeze(0), cos_g.unsqueeze(0), cos_b.unsqueeze(0)))).detach().cpu().item()

            # SSIM
            ssim_fct = StructuralSimilarityIndexMeasure(data_range=255).to(device)
            ssim = ssim_fct(tensor_original.unsqueeze(0), tensor_predicted.unsqueeze(0)).detach().cpu().item()

            # MSE
            mean_squared_error_fct = MeanSquaredError(squared=False).to(device)
            mse_l = mean_squared_error_fct(tensor_luminance_original, tensor_luminance_predicted).detach().cpu().item()
            mse_b = mean_squared_error_fct(tensor_original_dif_gauss, tensor_predicted_dif_gauss).detach().cpu().item()

            image.append(image_file[:4])
            if ssim > 0.8 or cos_rgb > 0.9 or cos_l > 0.92 or mse_l < 40 or mse_b < 12:
                video_pred.append(video_name[:4])
                minutage_pred.append(video_timestamp)
            else:
                video_pred.append("out")
                minutage_pred.append("")

    df_csv = pd.DataFrame({"image": image,
                           "video_pred": video_pred,
                           "minutage_pred": minutage_pred
                           })
    df_csv.to_csv(f"{csv_name}.csv", index=False)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:02<00:00, 44.8MB/s]

# %%
# Génère le fichier annoy
# Le fichier généré est disponible ici : https://drive.google.com/file/d/1A-W9iZ_XbYTEcuQ9wRHCjACNxSmEvvcr/view?usp=sharing
video_process()
# Out:
# 100%|██████████| 100/100 [14:05<00:00,  8.46s/it]

# %%
# Recherche sur les requêts tests
test_dir("data/test/png/", "results/test_png")
test_dir("data/test/jpeg/", "results/test_jpeg")
# Out:
# results/test_png: 100%|██████████| 300/300 [02:17<00:00,  2.18it/s]
# results/test_jpeg: 100%|██████████| 300/300 [02:03<00:00,  2.43it/s]

# %%
# !python src/evaluate.py --file=results/test_png.csv --file_gt=data/test/test_gt.csv
# Out:
# Taux de bonnes réponses : 99.3% (298/300)
# Ecart temporel moyen : 0.00 sec

# %%
# !python src/evaluate.py --file=results/test_jpeg.csv --file_gt=data/test/test_gt.csv
# Out:
# Taux de bonnes réponses : 99.7% (299/300)
# Ecart temporel moyen : 0.31 sec

# %% [markdown]
# ## Q4.

# %%
# Recherche sur les requêts challenge
test_dir("data/challenge/png/", "results/challenge_png")
test_dir("data/challenge/jpeg/", "results/challenge_jpeg")
# Out:
# results/challenge_png: 100%|██████████| 300/300 [02:15<00:00,  2.21it/s]
# results/challenge_jpeg: 100%|██████████| 300/300 [02:02<00:00,  2.45it/s]
